# %%
import cv2
import os
import matplotlib.pyplot as plt
from random import randint
import imutils

# %%
vidcap = cv2.VideoCapture(r"../data/Suppression Drone 6-24-2022.mov")
success,image = vidcap.read()

print(len(image))
# Out:
# 1920

# %%
count = 0
while success:
    cv2.imwrite("frame%d.jpg" % count, image)
    success,image = vidcap.read()
    print("Read a new frame: ",success)
    count+=1
# Out:
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...

# %%
folder = "../src"
imgs = []
for filename in os.listdir(folder):
    img = cv2.imread(os.path.join(folder,filename))
    if img is not None:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        imgs.append(img)

# %%
# Display imgs tensor to see
img_test = []
for i in range(3):
    img_test.append(imgs[i])
plt.imshow(img_test[1])
plt.show()

# %%
#"Test an arbitary image
print(len(imgs))
index = randint(0,len(imgs))
plt.imshow(imgs[index])
plt.show()
# Out:
# 2389

# %%
stitchy=cv2.Stitcher_create()

# %%
stitchy.create()
# Out:
# < cv2.Stitcher 000001C4B1152A90>

# %%
(status,stitched) = stitchy.stitch(img_test)

# %%
# final output
plt.imshow(stitched)

plt.show()
